# %%
from config1 import *
import requests

# %%
url = "https://skyscanner-skyscanner-flight-search-v1.p.rapidapi.com/apiservices/autosuggest/v1.0/UK/GBP/en-GB/"

params = {"query":"Munich"}

#headers = {'x-rapidapi-host': "skyscanner-skyscanner-flight-search-v1.p.rapidapi.com",
#                      'x-rapidapi-key': "<introduce your RapidAPI key here>"}

headers = {'x-rapidapi-host': "skyscanner-skyscanner-flight-search-v1.p.rapidapi.com",
                      'x-rapidapi-key': x_rapid_key}

# Notice the additional keywords here (headers, params)
response = requests.get(url, headers = headers, params = params)

# %%
import requests
url = "https://skyscanner-skyscanner-flight-search-v1.p.rapidapi.com/apiservices/browseroutes/v1.0/DE/EUR/en-US/MUC-sky/BER-sky/2021-03-15"
querystring = {"inboundpartialdate":"2019-12-01"}
headers = {
    'x-rapidapi-key': "71ef981e66mshdf2063b9d33878ep192e94jsn503202ed9c07",
    'x-rapidapi-host': "skyscanner-skyscanner-flight-search-v1.p.rapidapi.com"
    }
response = requests.request("GET", url, headers=headers, params=querystring)
print(response.text)
# Out:
# {
#   "Quotes" : [ {
#     "QuoteId" : 1,
#     "MinPrice" : 104,
#     "Direct" : true,
#     "OutboundLeg" : {
#       "CarrierIds" : [ 1368 ],
#       "OriginId" : 68611,
#       "DestinationId" : 42514,
#       "DepartureDate" : "2021-03-15T00:00:00"
#     },
#     "QuoteDateTime" : "2021-02-23T09:37:00"
#   } ],
#   "Carriers" : [ {
#     "CarrierId" : 1368,
#     "Name" : "Lufthansa"
#   } ],
#   "Places" : [ {
#     "Name" : "Berlin Brandenburg",
#     "Type" : "Station",
#     "PlaceId" : 42514,
#     "IataCode" : "BER",
#     "SkyscannerCode" : "BER",
#     "CityName" : "Berlin",
#     "CityId" : "BERL",
#     "CountryName" : "Germany"
#   }, {
#     "Name" : "Munich",
#     "Type" : "Station",
#     "PlaceId" : 68611,
#     "IataCode" : "MUC",
#     "SkyscannerCode" : "MUC",
#     "CityName" : "Munich",
#     "CityId" : "MUNI",
#     "CountryName" : "Germany"
#   } ],
#   "Currencies" : [ {
#     "Code" : "EUR",
#     "Symbol" : "â‚¬",
#     "ThousandsSeparator" : ".",
#     "DecimalSeparator" : ",",
#     "SymbolOnLeft" : false,
#     "SpaceBetweenAmountAndSymbol" : true,
#     "RoundingCoefficient" : 0,
#     "DecimalDigits" : 2
#   } ],
#   "Routes" : [ {
#     "QuoteDateTime" : "2021-02-23T09:37:00",
#     "Price" : 104,
#     "QuoteIds" : [ 1 ],
#     "OriginId" : 68611,
#     "DestinationId" : 42514
#   } ]
# }

# %%
def city_code(city_name):
    url = "https://skyscanner-skyscanner-flight-search-v1.p.rapidapi.com/apiservices/autosuggest/v1.0/US/USD/en-US/"
    params = {"query":city_name}
    headers = {'x-rapidapi-host': "skyscanner-skyscanner-flight-search-v1.p.rapidapi.com",
                      'x-rapidapi-key': x_rapid_key}

    response = requests.get(url, headers = headers, params = params)
    return response.json()['Places'][0]['PlaceId']

# %%
city_code("Mumbai")
# Out:
# 'BOM-sky'

# %%
def flight_prices(departure, arrival, date):

    departure_code = city_code(departure)
    arrival_code = city_code(arrival)
    url = f"https://skyscanner-skyscanner-flight-search-v1.p.rapidapi.com/apiservices/browsequotes/v1.0/US/USD/en-US/{departure_code}/{arrival_code}/{date}"

    params = {"inboundpartialdate":{date}}

    #headers = {
    #'x-rapidapi-host': "skyscanner-skyscanner-flight-search-v1.p.rapidapi.com",
    #'x-rapidapi-key': "<introduce your RapidAPI key here>"}

    headers = {
    'x-rapidapi-host': "skyscanner-skyscanner-flight-search-v1.p.rapidapi.com",
    'x-rapidapi-key': x_rapid_key}

    response = requests.get(url, headers=headers, params=params)

    return response.json()

flight_prices('Paris', 'London','2021-12-10')
# Out:
# {'Quotes': [{'QuoteId': 1,
#    'MinPrice': 47,
#    'Direct': True,
#    'OutboundLeg': {'CarrierIds': [50441],
#     'OriginId': 44759,
#     'DestinationId': 66270,
#     'DepartureDate': '2021-12-10T00:00:00'},
#    'QuoteDateTime': '2021-02-23T15:42:00'}],
#  'Carriers': [{'CarrierId': 50441, 'Name': 'easyJet'}],
#  'Places': [{'Name': 'Paris Charles de Gaulle',
#    'Type': 'Station',
#    'PlaceId': 44759,
#    'IataCode': 'CDG',
#    'SkyscannerCode': 'CDG',
#    'CityName': 'Paris',
#    'CityId': 'PARI',
#    'CountryName': 'France'},
#   {'Name': 'London Luton',
#    'Type': 'Station',
#    'PlaceId': 66270,
#    'IataCode': 'LTN',
#    'SkyscannerCode': 'LTN',
#    'CityName': 'London',
#    'CityId': 'LOND',
#    'CountryName': 'United Kingdom'},
#   {'Name': 'Paris',
#    'Type': 'City',
#    'PlaceId': 3579769,
#    'SkyscannerCode': 'PARI',
#    'CityId': 'PARI',
#    'CountryName': 'France'}],
#  'Currencies': [{'Code': 'USD',
#    'Symbol': '$',
#    'ThousandsSeparator': ',',
#    'DecimalSeparator': '.',
#    'SymbolOnLeft': True,
#    'SpaceBetweenAmountAndSymbol': False,
#    'RoundingCoefficient': 0,
#    'DecimalDigits': 2}]}

# %% [markdown]
# Following the class example, create a function that returns the price, names of origin and arrival airports and the name of the company. Do it for all the flights between two dates that cost the same.

# %%
import pandas as pd
def get_dates(start, end):
    return pd.Series(pd.date_range(start, end,freq='d').format()) # Format makes the output ans str variable.

get_dates('1992-01-01','1992-01-20')
# Out:
# 0     1992-01-01
# 1     1992-01-02
# 2     1992-01-03
# 3     1992-01-04
# 4     1992-01-05
# 5     1992-01-06
# 6     1992-01-07
# 7     1992-01-08
# 8     1992-01-09
# 9     1992-01-10
# 10    1992-01-11
# 11    1992-01-12
# 12    1992-01-13
# 13    1992-01-14
# 14    1992-01-15
# 15    1992-01-16
# 16    1992-01-17
# 17    1992-01-18
# 18    1992-01-19
# 19    1992-01-20
# dtype: object

# %%
from  time import sleep

def flight_days(origin, destination, start, end):
    dates = get_dates(start, end)
    my_dict = {}
    for date in list(dates):
        #result = None
        #while (result == None):
            try: 
                #print(date)
                #print("Gathering fligths")
                result = flight_prices(origin, destination, date)
                my_dict[date] = result
                sleep(5)
            except: 
                print("Error from the API")
                sleep(60)
    return my_dict

#flight_days('Paris','Barcelona','2020-11-26','2020-12-10')

# %%
flights = flight_days('Barcelona','London','2021-11-26','2021-12-10')

# %%
flights
# Out:
# {'2021-11-26': {'Quotes': [{'QuoteId': 1,
#     'MinPrice': 27,
#     'Direct': True,
#     'OutboundLeg': {'CarrierIds': [50441],
#      'OriginId': 42414,
#      'DestinationId': 66270,
#      'DepartureDate': '2021-11-26T00:00:00'},
#     'QuoteDateTime': '2021-02-23T15:41:00'}],
#   'Carriers': [{'CarrierId': 50441, 'Name': 'easyJet'}],
#   'Places': [{'Name': 'Barcelona',
#     'Type': 'Station',
#     'PlaceId': 42414,
#     'IataCode': 'BCN',
#     'SkyscannerCode': 'BCN',
#     'CityName': 'Barcelona',
#     'CityId': 'BARC',
#     'CountryName': 'Spain'},
#    {'Name': 'London Luton',
#     'Type': 'Station',
#     'PlaceId': 66270,
#     'IataCode': 'LTN',
#     'SkyscannerCode': 'LTN',
#     'CityName': 'London',
#     'CityId': 'LOND',
#     'CountryName': 'United Kingdom'}],
#   'Currencies': [{'Code': 'USD',
#     'Symbol': '$',
#     'ThousandsSeparator': ',',
#     'DecimalSeparator': '.',
#     'SymbolOnLeft': True,
#     'SpaceBetweenAmountAndSymbol': False,
#     'RoundingCoefficient': 0,
#     'DecimalDigits': 2}]},
#  '2021-11-27': {'Quotes': [{'QuoteId': 1,
#     'MinPrice': 27,
#     'Direct': True,
#     'OutboundLeg': {'CarrierIds': [50441],
#      'OriginId': 42414,
#      'DestinationId': 66270,
#      'DepartureDate': '2021-11-27T00:00:00'},
#     'QuoteDateTime': '2021-02-23T15:41:00'}],
#   'Carriers': [{'CarrierId': 50441, 'Name': 'easyJet'}],
#   'Places': [{'Name': 'Barcelona',
#     'Type': 'Station',
#     'PlaceId': 42414,
#     'IataCode': 'BCN',
#     'SkyscannerCode': 'BCN',
#     'CityName': 'Barcelona',
#     'CityId': 'BARC',
#     'CountryName': 'Spain'},
#    {'Name': 'London Luton',
#     'Type': 'Station',
#     'PlaceId': 66270,
#     'IataCode': 'LTN',
#     'SkyscannerCode': 'LTN',
#     'CityName': 'London',
#     'CityId': 'LOND',
#     'CountryName': 'United Kingdom'}],
#   'Currencies': [{'Code': 'USD',
#     'Symbol': '$',
#     'ThousandsSeparator': ',',
#     'DecimalSeparator': '.',
#     'SymbolOnLeft': True,
#     'SpaceBetweenAmountAndSymbol': False,
#     'RoundingCoefficient': 0,
#     'DecimalDigits': 2}]},
#  '2021-11-28': {'Quotes': [{'QuoteId': 1,
#     'MinPrice': 27,
#     'Direct': True,
#     'OutboundLeg': {'CarrierIds': [50441],
#      'OriginId': 42414,
#      'DestinationId': 65655,
#      'DepartureDate': '2021-11-28T00:00:00'},
#     'QuoteDateTime': '2021-02-23T15:41:00'}],
#   'Carriers': [{'CarrierId': 50441, 'Name': 'easyJet'}],
#   'Places': [{'Name': 'Barcelona',
#     'Type': 'Station',
#     'PlaceId': 42414,
#     'IataCode': 'BCN',
#     'SkyscannerCode': 'BCN',
#     'CityName': 'Barcelona',
#     'CityId': 'BARC',
#     'CountryName': 'Spain'},
#    {'Name': 'London Gatwick',
#     'Type': 'Station',
#     'PlaceId': 65655,
#     'IataCode': 'LGW',
#     'SkyscannerCode': 'LGW',
#     'CityName': 'London',
#     'CityId': 'LOND',
#     'CountryName': 'United Kingdom'}],
#   'Currencies': [{'Code': 'USD',
#     'Symbol': '$',
#     'ThousandsSeparator': ',',
#     'DecimalSeparator': '.',
#     'SymbolOnLeft': True,
#     'SpaceBetweenAmountAndSymbol': False,
#     'RoundingCoefficient': 0,
#     'DecimalDigits': 2}]},
#  '2021-11-29': {'Quotes': [{'QuoteId': 1,
#     'MinPrice': 27,
#     'Direct': True,
#     'OutboundLeg': {'CarrierIds': [50441],
#      'OriginId': 42414,
#      'DestinationId': 65655,
#      'DepartureDate': '2021-11-29T00:00:00'},
#     'QuoteDateTime': '2021-02-23T15:41:00'}],
#   'Carriers': [{'CarrierId': 50441, 'Name': 'easyJet'}],
#   'Places': [{'Name': 'Barcelona',
#     'Type': 'Station',
#     'PlaceId': 42414,
#     'IataCode': 'BCN',
#     'SkyscannerCode': 'BCN',
#     'CityName': 'Barcelona',
#     'CityId': 'BARC',
#     'CountryName': 'Spain'},
#    {'Name': 'London Gatwick',
#     'Type': 'Station',
#     'PlaceId': 65655,
#     'IataCode': 'LGW',
#     'SkyscannerCode': 'LGW',
#     'CityName': 'London',
#     'CityId': 'LOND',
#     'CountryName': 'United Kingdom'}],
#   'Currencies': [{'Code': 'USD',
#     'Symbol': '$',
#     'ThousandsSeparator': ',',
#     'DecimalSeparator': '.',
#     'SymbolOnLeft': True,
#     'SpaceBetweenAmountAndSymbol': False,
#     'RoundingCoefficient': 0,
#     'DecimalDigits': 2}]},
#  '2021-11-30': {'Quotes': [{'QuoteId': 1,
#     'MinPrice': 27,
#     'Direct': True,
#     'OutboundLeg': {'CarrierIds': [50441],
#      'OriginId': 42414,
#      'DestinationId': 65655,
#      'DepartureDate': '2021-11-30T00:00:00'},
#     'QuoteDateTime': '2021-02-23T15:41:00'}],
#   'Carriers': [{'CarrierId': 50441, 'Name': 'easyJet'}],
#   'Places': [{'Name': 'Barcelona',
#     'Type': 'Station',
#     'PlaceId': 42414,
#     'IataCode': 'BCN',
#     'SkyscannerCode': 'BCN',
#     'CityName': 'Barcelona',
#     'CityId': 'BARC',
#     'CountryName': 'Spain'},
#    {'Name': 'London Gatwick',
#     'Type': 'Station',
#     'PlaceId': 65655,
#     'IataCode': 'LGW',
#     'SkyscannerCode': 'LGW',
#     'CityName': 'London',
#     'CityId': 'LOND',
#     'CountryName': 'United Kingdom'}],
#   'Currencies': [{'Code': 'USD',
#     'Symbol': '$',
#     'ThousandsSeparator': ',',
#     'DecimalSeparator': '.',
#     'SymbolOnLeft': True,
#     'SpaceBetweenAmountAndSymbol': False,
#     'RoundingCoefficient': 0,
#     'DecimalDigits': 2}]},
#  '2021-12-01': {'Quotes': [{'QuoteId': 1,
#     'MinPrice': 27,
#     'Direct': True,
#     'OutboundLeg': {'CarrierIds': [50441],
#      'OriginId': 42414,
#      'DestinationId': 66270,
#      'DepartureDate': '2021-12-01T00:00:00'},
#     'QuoteDateTime': '2021-02-23T15:41:00'}],
#   'Carriers': [{'CarrierId': 50441, 'Name': 'easyJet'}],
#   'Places': [{'Name': 'Barcelona',
#     'Type': 'Station',
#     'PlaceId': 42414,
#     'IataCode': 'BCN',
#     'SkyscannerCode': 'BCN',
#     'CityName': 'Barcelona',
#     'CityId': 'BARC',
#     'CountryName': 'Spain'},
#    {'Name': 'London Luton',
#     'Type': 'Station',
#     'PlaceId': 66270,
#     'IataCode': 'LTN',
#     'SkyscannerCode': 'LTN',
#     'CityName': 'London',
#     'CityId': 'LOND',
#     'CountryName': 'United Kingdom'}],
#   'Currencies': [{'Code': 'USD',
#     'Symbol': '$',
#     'ThousandsSeparator': ',',
#     'DecimalSeparator': '.',
#     'SymbolOnLeft': True,
#     'SpaceBetweenAmountAndSymbol': False,
#     'RoundingCoefficient': 0,
#     'DecimalDigits': 2}]},
#  '2021-12-02': {'Quotes': [{'QuoteId': 1,
#     'MinPrice': 24,
#     'Direct': True,
#     'OutboundLeg': {'CarrierIds': [50441],
#      'OriginId': 42414,
#      'DestinationId': 66270,
#      'DepartureDate': '2021-12-02T00:00:00'},
#     'QuoteDateTime': '2021-02-23T15:41:00'}],
#   'Carriers': [{'CarrierId': 50441, 'Name': 'easyJet'}],
#   'Places': [{'Name': 'Barcelona',
#     'Type': 'Station',
#     'PlaceId': 42414,
#     'IataCode': 'BCN',
#     'SkyscannerCode': 'BCN',
#     'CityName': 'Barcelona',
#     'CityId': 'BARC',
#     'CountryName': 'Spain'},
#    {'Name': 'London Luton',
#     'Type': 'Station',
#     'PlaceId': 66270,
#     'IataCode': 'LTN',
#     'SkyscannerCode': 'LTN',
#     'CityName': 'London',
#     'CityId': 'LOND',
#     'CountryName': 'United Kingdom'}],
#   'Currencies': [{'Code': 'USD',
#     'Symbol': '$',
#     'ThousandsSeparator': ',',
#     'DecimalSeparator': '.',
#     'SymbolOnLeft': True,
#     'SpaceBetweenAmountAndSymbol': False,
#     'RoundingCoefficient': 0,
#     'DecimalDigits': 2}]},
#  '2021-12-03': {'Quotes': [{'QuoteId': 1,
#     'MinPrice': 24,
#     'Direct': True,
#     'OutboundLeg': {'CarrierIds': [50441],
#      'OriginId': 42414,
#      'DestinationId': 66270,
#      'DepartureDate': '2021-12-03T00:00:00'},
#     'QuoteDateTime': '2021-02-23T15:41:00'}],
#   'Carriers': [{'CarrierId': 50441, 'Name': 'easyJet'}],
#   'Places': [{'Name': 'Barcelona',
#     'Type': 'Station',
#     'PlaceId': 42414,
#     'IataCode': 'BCN',
#     'SkyscannerCode': 'BCN',
#     'CityName': 'Barcelona',
#     'CityId': 'BARC',
#     'CountryName': 'Spain'},
#    {'Name': 'London Luton',
#     'Type': 'Station',
#     'PlaceId': 66270,
#     'IataCode': 'LTN',
#     'SkyscannerCode': 'LTN',
#     'CityName': 'London',
#     'CityId': 'LOND',
#     'CountryName': 'United Kingdom'}],
#   'Currencies': [{'Code': 'USD',
#     'Symbol': '$',
#     'ThousandsSeparator': ',',
#     'DecimalSeparator': '.',
#     'SymbolOnLeft': True,
#     'SpaceBetweenAmountAndSymbol': False,
#     'RoundingCoefficient': 0,
#     'DecimalDigits': 2}]},
#  '2021-12-04': {'Quotes': [{'QuoteId': 1,
#     'MinPrice': 33,
#     'Direct': True,
#     'OutboundLeg': {'CarrierIds': [50441],
#      'OriginId': 42414,
#      'DestinationId': 66270,
#      'DepartureDate': '2021-12-04T00:00:00'},
#     'QuoteDateTime': '2021-02-23T15:41:00'}],
#   'Carriers': [{'CarrierId': 50441, 'Name': 'easyJet'}],
#   'Places': [{'Name': 'Barcelona',
#     'Type': 'Station',
#     'PlaceId': 42414,
#     'IataCode': 'BCN',
#     'SkyscannerCode': 'BCN',
#     'CityName': 'Barcelona',
#     'CityId': 'BARC',
#     'CountryName': 'Spain'},
#    {'Name': 'London Luton',
#     'Type': 'Station',
#     'PlaceId': 66270,
#     'IataCode': 'LTN',
#     'SkyscannerCode': 'LTN',
#     'CityName': 'London',
#     'CityId': 'LOND',
#     'CountryName': 'United Kingdom'}],
#   'Currencies': [{'Code': 'USD',
#     'Symbol': '$',
#     'ThousandsSeparator': ',',
#     'DecimalSeparator': '.',
#     'SymbolOnLeft': True,
#     'SpaceBetweenAmountAndSymbol': False,
#     'RoundingCoefficient': 0,
#     'DecimalDigits': 2}]},
#  '2021-12-05': {'Quotes': [{'QuoteId': 1,
#     'MinPrice': 40,
#     'Direct': True,
#     'OutboundLeg': {'CarrierIds': [50441],
#      'OriginId': 42414,
#      'DestinationId': 65655,
#      'DepartureDate': '2021-12-05T00:00:00'},
#     'QuoteDateTime': '2021-02-23T15:41:00'}],
#   'Carriers': [{'CarrierId': 50441, 'Name': 'easyJet'}],
#   'Places': [{'Name': 'Barcelona',
#     'Type': 'Station',
#     'PlaceId': 42414,
#     'IataCode': 'BCN',
#     'SkyscannerCode': 'BCN',
#     'CityName': 'Barcelona',
#     'CityId': 'BARC',
#     'CountryName': 'Spain'},
#    {'Name': 'London Gatwick',
#     'Type': 'Station',
#     'PlaceId': 65655,
#     'IataCode': 'LGW',
#     'SkyscannerCode': 'LGW',
#     'CityName': 'London',
#     'CityId': 'LOND',
#     'CountryName': 'United Kingdom'}],
#   'Currencies': [{'Code': 'USD',
#     'Symbol': '$',
#     'ThousandsSeparator': ',',
#     'DecimalSeparator': '.',
#     'SymbolOnLeft': True,
#     'SpaceBetweenAmountAndSymbol': False,
#     'RoundingCoefficient': 0,
#     'DecimalDigits': 2}]},
#  '2021-12-06': {'Quotes': [{'QuoteId': 1,
#     'MinPrice': 30,
#     'Direct': True,
#     'OutboundLeg': {'CarrierIds': [50441],
#      'OriginId': 42414,
#      'DestinationId': 66270,
#      'DepartureDate': '2021-12-06T00:00:00'},
#     'QuoteDateTime': '2021-02-23T15:41:00'}],
#   'Carriers': [{'CarrierId': 50441, 'Name': 'easyJet'}],
#   'Places': [{'Name': 'Barcelona',
#     'Type': 'Station',
#     'PlaceId': 42414,
#     'IataCode': 'BCN',
#     'SkyscannerCode': 'BCN',
#     'CityName': 'Barcelona',
#     'CityId': 'BARC',
#     'CountryName': 'Spain'},
#    {'Name': 'London Luton',
#     'Type': 'Station',
#     'PlaceId': 66270,
#     'IataCode': 'LTN',
#     'SkyscannerCode': 'LTN',
#     'CityName': 'London',
#     'CityId': 'LOND',
#     'CountryName': 'United Kingdom'}],
#   'Currencies': [{'Code': 'USD',
#     'Symbol': '$',
#     'ThousandsSeparator': ',',
#     'DecimalSeparator': '.',
#     'SymbolOnLeft': True,
#     'SpaceBetweenAmountAndSymbol': False,
#     'RoundingCoefficient': 0,
#     'DecimalDigits': 2}]},
#  '2021-12-07': {'Quotes': [{'QuoteId': 1,
#     'MinPrice': 27,
#     'Direct': True,
#     'OutboundLeg': {'CarrierIds': [50441],
#      'OriginId': 42414,
#      'DestinationId': 65655,
#      'DepartureDate': '2021-12-07T00:00:00'},
#     'QuoteDateTime': '2021-02-23T15:41:00'}],
#   'Carriers': [{'CarrierId': 50441, 'Name': 'easyJet'}],
#   'Places': [{'Name': 'Barcelona',
#     'Type': 'Station',
#     'PlaceId': 42414,
#     'IataCode': 'BCN',
#     'SkyscannerCode': 'BCN',
#     'CityName': 'Barcelona',
#     'CityId': 'BARC',
#     'CountryName': 'Spain'},
#    {'Name': 'London Gatwick',
#     'Type': 'Station',
#     'PlaceId': 65655,
#     'IataCode': 'LGW',
#     'SkyscannerCode': 'LGW',
#     'CityName': 'London',
#     'CityId': 'LOND',
#     'CountryName': 'United Kingdom'}],
#   'Currencies': [{'Code': 'USD',
#     'Symbol': '$',
#     'ThousandsSeparator': ',',
#     'DecimalSeparator': '.',
#     'SymbolOnLeft': True,
#     'SpaceBetweenAmountAndSymbol': False,
#     'RoundingCoefficient': 0,
#     'DecimalDigits': 2}]},
#  '2021-12-08': {'Quotes': [{'QuoteId': 1,
#     'MinPrice': 27,
#     'Direct': True,
#     'OutboundLeg': {'CarrierIds': [50441],
#      'OriginId': 42414,
#      'DestinationId': 66270,
#      'DepartureDate': '2021-12-08T00:00:00'},
#     'QuoteDateTime': '2021-02-23T15:41:00'}],
#   'Carriers': [{'CarrierId': 50441, 'Name': 'easyJet'}],
#   'Places': [{'Name': 'Barcelona',
#     'Type': 'Station',
#     'PlaceId': 42414,
#     'IataCode': 'BCN',
#     'SkyscannerCode': 'BCN',
#     'CityName': 'Barcelona',
#     'CityId': 'BARC',
#     'CountryName': 'Spain'},
#    {'Name': 'London Luton',
#     'Type': 'Station',
#     'PlaceId': 66270,
#     'IataCode': 'LTN',
#     'SkyscannerCode': 'LTN',
#     'CityName': 'London',
#     'CityId': 'LOND',
#     'CountryName': 'United Kingdom'}],
#   'Currencies': [{'Code': 'USD',
#     'Symbol': '$',
#     'ThousandsSeparator': ',',
#     'DecimalSeparator': '.',
#     'SymbolOnLeft': True,
#     'SpaceBetweenAmountAndSymbol': False,
#     'RoundingCoefficient': 0,
#     'DecimalDigits': 2}]},
#  '2021-12-09': {'Quotes': [{'QuoteId': 1,
#     'MinPrice': 54,
#     'Direct': True,
#     'OutboundLeg': {'CarrierIds': [50441],
#      'OriginId': 42414,
#      'DestinationId': 65655,
#      'DepartureDate': '2021-12-09T00:00:00'},
#     'QuoteDateTime': '2021-02-23T15:40:00'}],
#   'Carriers': [{'CarrierId': 50441, 'Name': 'easyJet'}],
#   'Places': [{'Name': 'Barcelona',
#     'Type': 'Station',
#     'PlaceId': 42414,
#     'IataCode': 'BCN',
#     'SkyscannerCode': 'BCN',
#     'CityName': 'Barcelona',
#     'CityId': 'BARC',
#     'CountryName': 'Spain'},
#    {'Name': 'London Gatwick',
#     'Type': 'Station',
#     'PlaceId': 65655,
#     'IataCode': 'LGW',
#     'SkyscannerCode': 'LGW',
#     'CityName': 'London',
#     'CityId': 'LOND',
#     'CountryName': 'United Kingdom'}],
#   'Currencies': [{'Code': 'USD',
#     'Symbol': '$',
#     'ThousandsSeparator': ',',
#     'DecimalSeparator': '.',
#     'SymbolOnLeft': True,
#     'SpaceBetweenAmountAndSymbol': False,
#     'RoundingCoefficient': 0,
#     'DecimalDigits': 2}]},
#  '2021-12-10': {'Quotes': [{'QuoteId': 1,
#     'MinPrice': 24,
#     'Direct': True,
#     'OutboundLeg': {'CarrierIds': [1865],
#      'OriginId': 42414,
#      'DestinationId': 65655,
#      'DepartureDate': '2021-12-10T00:00:00'},
#     'QuoteDateTime': '2021-02-22T10:14:00'}],
#   'Carriers': [{'CarrierId': 1865, 'Name': 'Vueling Airlines'}],
#   'Places': [{'Name': 'Barcelona',
#     'Type': 'Station',
#     'PlaceId': 42414,
#     'IataCode': 'BCN',
#     'SkyscannerCode': 'BCN',
#     'CityName': 'Barcelona',
#     'CityId': 'BARC',
#     'CountryName': 'Spain'},
#    {'Name': 'London Gatwick',
#     'Type': 'Station',
#     'PlaceId': 65655,
#     'IataCode': 'LGW',
#     'SkyscannerCode': 'LGW',
#     'CityName': 'London',
#     'CityId': 'LOND',
#     'CountryName': 'United Kingdom'}],
#   'Currencies': [{'Code': 'USD',
#     'Symbol': '$',
#     'ThousandsSeparator': ',',
#     'DecimalSeparator': '.',
#     'SymbolOnLeft': True,
#     'SpaceBetweenAmountAndSymbol': False,
#     'RoundingCoefficient': 0,
#     'DecimalDigits': 2}]}}

# %%
#def lowest_price(origin, destination, start, end):
#    flights = flight_days(origin, destination, start, end)
#    prices = {date:min([quote["MinPrice"] for quote in flights[date]["Quotes"]]) for date in flights for quote in flights[date]["Quotes"]}
#    return min(prices, key = prices.get)

#flights = flight_prices('Barcelona','London','2020-11-26','2020-12-10')

#my_dict = {date1: [], date2: [],....}

my_dict = {}

for date in flights: # We iterate over the dates
    print("The flights for this date are: ")
    print(flights[date]['Quotes'])
    my_dict[date] = [] #We create an empty list of prices for the given date.
    for elem in flights[date]['Quotes']: # We iterate over "Quotes" of each day.
        my_dict[date].append(elem['MinPrice']) # We fill the date with the prices.
    print("The prices for this date are: ",my_dict[date])
    try:
        print("The min price for this date is: ",min(my_dict[date])) # We determine the minimum price.
    except:
        continue
# Out:
# The flights for this date are:
# [{'QuoteId': 1, 'MinPrice': 27, 'Direct': True, 'OutboundLeg': {'CarrierIds': [50441], 'OriginId': 42414, 'DestinationId': 66270, 'DepartureDate': '2021-11-26T00:00:00'}, 'QuoteDateTime': '2021-02-23T15:41:00'}]
# The prices for this date are:  [27]
# The min price for this date is:  27
# The flights for this date are:
# [{'QuoteId': 1, 'MinPrice': 27, 'Direct': True, 'OutboundLeg': {'CarrierIds': [50441], 'OriginId': 42414, 'DestinationId': 66270, 'DepartureDate': '2021-11-27T00:00:00'}, 'QuoteDateTime': '2021-02-23T15:41:00'}]
# The prices for this date are:  [27]
# The min price for this date is:  27
# The flights for this date are:
# [{'QuoteId': 1, 'MinPrice': 27, 'Direct': True, 'OutboundLeg': {'CarrierIds': [50441], 'OriginId': 42414, 'DestinationId': 65655, 'DepartureDate': '2021-11-28T00:00:00'}, 'QuoteDateTime': '2021-02-23T15:41:00'}]
# The prices for this date are:  [27]
# The min price for this date is:  27
# The flights for this date are:
# [{'QuoteId': 1, 'MinPrice': 27, 'Direct': True, 'OutboundLeg': {'CarrierIds': [50441], 'OriginId': 42414, 'DestinationId': 65655, 'DepartureDate': '2021-11-29T00:00:00'}, 'QuoteDateTime': '2021-02-23T15:41:00'}]
# The prices for this date are:  [27]
# The min price for this date is:  27
# The flights for this date are:
# [{'QuoteId': 1, 'MinPrice': 27, 'Direct': True, 'OutboundLeg': {'CarrierIds': [50441], 'OriginId': 42414, 'DestinationId': 65655, 'DepartureDate': '2021-11-30T00:00:00'}, 'QuoteDateTime': '2021-02-23T15:41:00'}]
# The prices for this date are:  [27]
# The min price for this date is:  27
# The flights for this date are:
# [{'QuoteId': 1, 'MinPrice': 27, 'Direct': True, 'OutboundLeg': {'CarrierIds': [50441], 'OriginId': 42414, 'DestinationId': 66270, 'DepartureDate': '2021-12-01T00:00:00'}, 'QuoteDateTime': '2021-02-23T15:41:00'}]
# The prices for this date are:  [27]
# The min price for this date is:  27
# The flights for this date are:
# [{'QuoteId': 1, 'MinPrice': 24, 'Direct': True, 'OutboundLeg': {'CarrierIds': [50441], 'OriginId': 42414, 'DestinationId': 66270, 'DepartureDate': '2021-12-02T00:00:00'}, 'QuoteDateTime': '2021-02-23T15:41:00'}]
# The prices for this date are:  [24]
# The min price for this date is:  24
# The flights for this date are:
# [{'QuoteId': 1, 'MinPrice': 24, 'Direct': True, 'OutboundLeg': {'CarrierIds': [50441], 'OriginId': 42414, 'DestinationId': 66270, 'DepartureDate': '2021-12-03T00:00:00'}, 'QuoteDateTime': '2021-02-23T15:41:00'}]
# The prices for this date are:  [24]
# The min price for this date is:  24
# The flights for this date are:
# [{'QuoteId': 1, 'MinPrice': 33, 'Direct': True, 'OutboundLeg': {'CarrierIds': [50441], 'OriginId': 42414, 'DestinationId': 66270, 'DepartureDate': '2021-12-04T00:00:00'}, 'QuoteDateTime': '2021-02-23T15:41:00'}]
# The prices for this date are:  [33]
# The min price for this date is:  33
# The flights for this date are:
# [{'QuoteId': 1, 'MinPrice': 40, 'Direct': True, 'OutboundLeg': {'CarrierIds': [50441], 'OriginId': 42414, 'DestinationId': 65655, 'DepartureDate': '2021-12-05T00:00:00'}, 'QuoteDateTime': '2021-02-23T15:41:00'}]
# The prices for this date are:  [40]
# The min price for this date is:  40
# The flights for this date are:
# [{'QuoteId': 1, 'MinPrice': 30, 'Direct': True, 'OutboundLeg': {'CarrierIds': [50441], 'OriginId': 42414, 'DestinationId': 66270, 'DepartureDate': '2021-12-06T00:00:00'}, 'QuoteDateTime': '2021-02-23T15:41:00'}]
# The prices for this date are:  [30]
# The min price for this date is:  30
# The flights for this date are:
# [{'QuoteId': 1, 'MinPrice': 27, 'Direct': True, 'OutboundLeg': {'CarrierIds': [50441], 'OriginId': 42414, 'DestinationId': 65655, 'DepartureDate': '2021-12-07T00:00:00'}, 'QuoteDateTime': '2021-02-23T15:41:00'}]
# The prices for this date are:  [27]
# The min price for this date is:  27
# The flights for this date are:
# [{'QuoteId': 1, 'MinPrice': 27, 'Direct': True, 'OutboundLeg': {'CarrierIds': [50441], 'OriginId': 42414, 'DestinationId': 66270, 'DepartureDate': '2021-12-08T00:00:00'}, 'QuoteDateTime': '2021-02-23T15:41:00'}]
# The prices for this date are:  [27]
# The min price for this date is:  27
# The flights for this date are:
# [{'QuoteId': 1, 'MinPrice': 54, 'Direct': True, 'OutboundLeg': {'CarrierIds': [50441], 'OriginId': 42414, 'DestinationId': 65655, 'DepartureDate': '2021-12-09T00:00:00'}, 'QuoteDateTime': '2021-02-23T15:40:00'}]
# The prices for this date are:  [54]
# The min price for this date is:  54
# The flights for this date are:
# [{'QuoteId': 1, 'MinPrice': 24, 'Direct': True, 'OutboundLeg': {'CarrierIds': [1865], 'OriginId': 42414, 'DestinationId': 65655, 'DepartureDate': '2021-12-10T00:00:00'}, 'QuoteDateTime': '2021-02-22T10:14:00'}]
# The prices for this date are:  [24]
# The min price for this date is:  24

# %%
#def lowest_price(origin, destination, start, end):
#    flights = flight_days(origin, destination, start, end)
#    prices = {date:min([quote["MinPrice"] for quote in flights[date]["Quotes"]]) for date in flights for quote in flights[date]["Quotes"]}
#    return min(prices, key = prices.get)

#flights = flight_prices('Barcelona','London','2020-11-26','2020-12-10')

#my_dict = {date1: [], date2: [],....}

my_dict = {}

for date in flights: # We iterate over the dates
    print("The flights for this date are: ")
    print('Price:', flights[date]['Quotes'][0]['MinPrice'],'\nName origin:', flights[date]['Places'][0]['Name'],'\nName arrival:', flights[date]['Places'][1]['Name'],'\nAirline:', flights[date]['Carriers'][0]['Name'])
    price_list = []
    for i in range(len(flights[date]['Quotes'][0]['MinPrice']))
# Out:
# The flights for this date are:
# Price: 27
# Name origin: Barcelona
# Name arrival: London Luton
# Airline: easyJet
# The prices for this date are:  [27]
# The min price for this date is:  27
# The flights for this date are:
# Price: 27
# Name origin: Barcelona
# Name arrival: London Luton
# Airline: easyJet
# The prices for this date are:  [27]
# The min price for this date is:  27
# The flights for this date are:
# Price: 27
# Name origin: Barcelona
# Name arrival: London Gatwick
# Airline: easyJet
# The prices for this date are:  [27]
# The min price for this date is:  27
# The flights for this date are:
# Price: 27
# Name origin: Barcelona
# Name arrival: London Gatwick
# Airline: easyJet
# The prices for this date are:  [27]
# The min price for this date is:  27
# The flights for this date are:
# Price: 27
# Name origin: Barcelona
# Name arrival: London Gatwick
# Airline: easyJet
# The prices for this date are:  [27]
# The min price for this date is:  27
# The flights for this date are:
# Price: 27
# Name origin: Barcelona
# Name arrival: London Luton
# Airline: easyJet
# The prices for this date are:  [27]
# The min price for this date is:  27
# The flights for this date are:
# Price: 24
# Name origin: Barcelona
# Name arrival: London Luton
# Airline: easyJet
# The prices for this date are:  [24]
# The min price for this date is:  24
# The flights for this date are:
# Price: 24
# Name origin: Barcelona
# Name arrival: London Luton
# Airline: easyJet
# The prices for this date are:  [24]
# The min price for this date is:  24
# The flights for this date are:
# Price: 33
# Name origin: Barcelona
# Name arrival: London Luton
# Airline: easyJet
# The prices for this date are:  [33]
# The min price for this date is:  33
# The flights for this date are:
# Price: 40
# Name origin: Barcelona
# Name arrival: London Gatwick
# Airline: easyJet
# The prices for this date are:  [40]
# The min price for this date is:  40
# The flights for this date are:
# Price: 30
# Name origin: Barcelona
# Name arrival: London Luton
# Airline: easyJet
# The prices for this date are:  [30]
# The min price for this date is:  30
# The flights for this date are:
# Price: 27
# Name origin: Barcelona
# Name arrival: London Gatwick
# Airline: easyJet
# The prices for this date are:  [27]
# The min price for this date is:  27
# The flights for this date are:
# Price: 27
# Name origin: Barcelona
# Name arrival: London Luton
# Airline: easyJet
# The prices for this date are:  [27]
# The min price for this date is:  27
# The flights for this date are:
# Price: 54
# Name origin: Barcelona
# Name arrival: London Gatwick
# Airline: easyJet
# The prices for this date are:  [54]
# The min price for this date is:  54
# The flights for this date are:
# Price: 24
# Name origin: Barcelona
# Name arrival: London Gatwick
# Airline: Vueling Airlines
# The prices for this date are:  [24]
# The min price for this date is:  24

# %%
def repeat(x):
    _size = len(x)
    repeated = []
    for i in range(_size):
        k = i + 1
        for j in range(k, _size):
            if x[i] == x[j] and x[i] not in repeated:
                repeated.append(x[i])
    return repeated
import re
my_dict = {}
store_dict = []
store_price = []
for date in flights: # We iterate over the dates
    my_dict[date] = [] #We create an empty list of prices for the given date.
    min_price = 10000
    best_date = ""
    for elem in flights[date]['Quotes']: # We iterate over “Quotes” of each day.
        my_dict[date].append(elem['MinPrice']) # We fill the date with the prices.
        if (elem['MinPrice'] == min_price):
            min_price = elem['MinPrice']
            best_date = date
    try:
        store_dict.append([{'Price': flights[date]['Quotes'][0]['MinPrice'],
                           'Name origin': flights[date]['Places'][0]['Name'],
                           'Name arrival': flights[date]['Places'][1]['Name'],
                           'Airline': flights[date]['Carriers'][0]['Name'],
                           'Date': flights[date]['Quotes'][0]['OutboundLeg']['DepartureDate'][:-9]
                           }])
        #print(“The min price for this date is: “,min(my_dict[date])) # We determine the minimum price.
    except:
        continue
for elem in store_dict:
    store_price.append(elem[0]['Price'])
for i in store_dict:
    if i[0]['Price'] in repeat(store_price):
        print(i)
# Out:
# []
# [{'Price': 27, 'Name origin': 'Barcelona', 'Name arrival': 'London Luton', 'Airline': 'easyJet', 'Date': '2021-11-26'}]
# [{'Price': 27, 'Name origin': 'Barcelona', 'Name arrival': 'London Luton', 'Airline': 'easyJet', 'Date': '2021-11-27'}]
# [{'Price': 27, 'Name origin': 'Barcelona', 'Name arrival': 'London Gatwick', 'Airline': 'easyJet', 'Date': '2021-11-28'}]
# [{'Price': 27, 'Name origin': 'Barcelona', 'Name arrival': 'London Gatwick', 'Airline': 'easyJet', 'Date': '2021-11-29'}]
# [{'Price': 27, 'Name origin': 'Barcelona', 'Name arrival': 'London Gatwick', 'Airline': 'easyJet', 'Date': '2021-11-30'}]
# [{'Price': 27, 'Name origin': 'Barcelona', 'Name arrival': 'London Luton', 'Airline': 'easyJet', 'Date': '2021-12-01'}]
# [{'Price': 24, 'Name origin': 'Barcelona', 'Name arrival': 'London Luton', 'Airline': 'easyJet', 'Date': '2021-12-02'}]
# [{'Price': 24, 'Name origin': 'Barcelona', 'Name arrival': 'London Luton', 'Airline': 'easyJet', 'Date': '2021-12-03'}]
# [{'Price': 27, 'Name origin': 'Barcelona', 'Name arrival': 'London Gatwick', 'Airline': 'easyJet', 'Date': '2021-12-07'}]
# [{'Price': 27, 'Name origin': 'Barcelona', 'Name arrival': 'London Luton', 'Airline': 'easyJet', 'Date': '2021-12-08'}]
# [{'Price': 24, 'Name origin': 'Barcelona', 'Name arrival': 'London Gatwick', 'Airline': 'Vueling Airlines', 'Date': '2021-12-10'}]
